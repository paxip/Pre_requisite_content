# %%
#loading page by month and by year.

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

from selenium.webdriver.support.ui import WebDriverWait, Select




class Scraper:
    def load_webpage():
        URL = "https://www.boxofficemojo.com/"
        driverpath = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5'
        service = Service(driverpath)
        chrome_options = Options()
        driver = webdriver.Chrome(options=chrome_options, service=service) 
        driver.get(URL)
        time.sleep(3)

        tab_container = driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = tab_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

        drop_down_by_year = driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_by_year)

        select.select_by_visible_text('By year')
        time.sleep(3)

        drop_down_by_month = driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
        select = Select(drop_down_by_month)

        select.select_by_visible_text('2017')
        time.sleep(5)

        movie_table = driver.find_element(by=By.XPATH, value='//*[@id="table"]') 
        movie_list = driver.find_element(by=By.XPATH, value='//th[@class="a-text-left mojo-field-type-genre hidden mojo-sortable-column hidden a-nowrap"]') 
        #movie_list = driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]')
        link_list = []

        for movie in movie_list:
            row = driver.find_element(by=By.XPATH, value='//<tr><td[@class="a-text-left mojo-header-column mojo-truncate mojo-field-type-named_interval mojo-sort-column"]') 
            
            
            
            #a_tag = movie.find_element(by=By.XPATH, value='//a[@class="a-link-normal"]')
            #link = a_tag.get_attribute('href')
            #link_list.append(link)

        #print(f'There are {len(link_list)} properties in this page')
        #print(link_list)

        

        return driver

    #def get_links():
        #driver = Scraper.load_webpage()
        #movie_table = driver.find_element(by=By.XPATH, value='//select[@class="by-year-navSelector"]')





       
    #Javascript command tested by Ivan:
    #driver.execute_script("arguments[0].click();", drop_down)




        


   

        
Scraper.load_webpage()

# %%
#load page by month and year and navigate to movie link

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:
    def load_webpage():
        URL = "https://www.boxofficemojo.com/"
        driverpath = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5'
        service = Service(driverpath)
        chrome_options = Options()
        driver = webdriver.Chrome(options=chrome_options, service=service) 
        driver.get(URL)
        time.sleep(3)

        tab_container = driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = tab_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

        drop_down_by_year = driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_by_year)

        select.select_by_visible_text('By year')
        time.sleep(3)

        drop_down_by_month = driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
        select = Select(drop_down_by_month)

        select.select_by_visible_text('2017')
        time.sleep(5)

        movie_table = driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
        table_row = movie_table.find_elements(by=By.XPATH, value='./tr')
        movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')



Scraper.load_webpage()

# %%
#get all movie links from years 2017 to 2022 and print in a list

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:
    
    def load_webpage():
        URL = "https://www.boxofficemojo.com/"
        driverpath = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5'
        service = Service(driverpath)
        chrome_options = Options()
        driver = webdriver.Chrome(options=chrome_options, service=service) 
        driver.get(URL)
        time.sleep(3)

        tab_container = driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = tab_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

        drop_down_list = driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)

        select.select_by_visible_text('By year')
        time.sleep(3)


        for year in ('2017','2018','2019','2020','2021','2022'):
            drop_down_by_year = driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            table_row = movie_table.find_elements(by=By.XPATH, value='./tr')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            link_list = []

            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                link_list.append(link)
            
        
            print(f'There are {len(link_list)} movies on this page')
            print(link_list)



Scraper.load_webpage()
# Out:
# There are 12 movies on this page
# ['https://www.boxofficemojo.com/release/rl2708702721/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2959312385/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl444564993/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3481241089/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2541716993/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl863208961/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl578455041/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl2976089601/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl1767212545/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl222594561/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl660506113/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl2557707777/?ref_=bo_my_table_12']
# There are 12 movies on this page
# ['https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3075966465/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl2734720513/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1493206529/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2449573377/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2088535553/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl2071758337/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3095234049/?ref_=bo_my_table_12']
# There are 12 movies on this page
# ['https://www.boxofficemojo.com/release/rl3305145857/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2424210945/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl252151297/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1107461633/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2919400961/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl3321923073/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl3798500865/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3059975681/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3059975681/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3009644033/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl1517848065/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_12']
# There are 12 movies on this page
# ['https://www.boxofficemojo.com/release/rl3624109569/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3209528833/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl1442940417/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1442940417/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2141815297/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl1807647233/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl826311425/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl716997121/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl4205937153/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3433267713/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl4244997633/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl1182631425/?ref_=bo_my_table_12']
# There are 12 movies on this page
# ['https://www.boxofficemojo.com/release/rl2869659137/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2138867201/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl1908310529/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3490022913/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl1158252033/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2122089985/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl192906753/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl2819065345/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl1383892481/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3781723649/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl2399766017/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3624109569/?ref_=bo_my_table_12']
# There are 10 movies on this page
# ['https://www.boxofficemojo.com/release/rl2982445825/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2551874305/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl192905985/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1736214017/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2500036097/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl3724903937/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl1363641089/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl67732993/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl2977334785/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl2869659137/?ref_=bo_my_table_10']

# %%
#get all movie links for year 2017 and print in a list

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:
    def load_webpage():
        URL = "https://www.boxofficemojo.com/"
        driverpath = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5'
        service = Service(driverpath)
        chrome_options = Options()
        driver = webdriver.Chrome(options=chrome_options, service=service) 
        driver.get(URL)
        time.sleep(3)

        tab_container = driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = tab_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

        drop_down_list = driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)

        select.select_by_visible_text('By year')
        time.sleep(3)

        drop_down_by_year = driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
        select = Select(drop_down_by_year)

        select.select_by_visible_text('2017')
        time.sleep(5)

        movie_table = driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
        table_row = movie_table.find_elements(by=By.XPATH, value='./tr')
        movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
        link_list = []

        for movie in movie_list:
            a_tag = movie.find_element(by=By.TAG_NAME, value='a')
            link = a_tag.get_attribute('href')
            link_list.append(link)
            
        
        print(f'There are {len(link_list)} movies on this page')
        print(link_list)



Scraper.load_webpage()

# %%
#init method

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

from selenium.webdriver.support.ui import WebDriverWait, Select



class Scraper:
    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)

        pass

# %%
#get all movie links from years 2017 to 2022 and print in a list

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:
    
    def load_webpage():
        URL = "https://www.boxofficemojo.com/"
        driverpath = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5'
        service = Service(driverpath)
        chrome_options = Options()
        driver = webdriver.Chrome(options=chrome_options, service=service) 
        driver.get(URL)
        time.sleep(3)

        tab_container = driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = tab_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

        drop_down_list = driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)

        select.select_by_visible_text('By year')
        time.sleep(3)

        for year in ('2017','2018','2019','2020','2021','2022'):
            drop_down_by_year = driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select_option = Select(drop_down_by_year)
            select_option.select_by_visible_text(year)
            time.sleep(5)

            movie_table = driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            #table_row = movie_table.find_elements(by=By.XPATH, value='./tr')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            link_list = []

            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                link_list.append(link)
            
        
            print(f'There are {len(link_list)} movies on this page')
            print(link_list)



Scraper.load_webpage()

# %%
# Out:
# ['https://www.boxofficemojo.com/release/rl2708702721/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2959312385/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl444564993/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3481241089/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2541716993/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl863208961/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl578455041/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl2976089601/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl1767212545/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl222594561/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl660506113/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl2557707777/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3075966465/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl2734720513/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1493206529/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2449573377/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2088535553/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl2071758337/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3095234049/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3305145857/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2424210945/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl252151297/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1107461633/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2919400961/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl3321923073/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl3798500865/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3059975681/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3059975681/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3009644033/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl1517848065/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3624109569/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3209528833/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl1442940417/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1442940417/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2141815297/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl1807647233/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl826311425/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl716997121/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl4205937153/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3433267713/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl4244997633/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl1182631425/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl2869659137/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2138867201/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl1908310529/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3490022913/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl1158252033/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2122089985/?ref_=bo_my_table_6', ...

# %%
#full code with links stored in one list.

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        link_list = []
        
        for year in ('2017','2018','2019','2020','2021','2022'):
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                link_list.append(link)

        print(link_list)
            


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
# Out:
# ['https://www.boxofficemojo.com/release/rl2708702721/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2959312385/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl444564993/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3481241089/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2541716993/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl863208961/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl578455041/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl2976089601/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl1767212545/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl222594561/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl660506113/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl2557707777/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3075966465/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl2734720513/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1493206529/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2449573377/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2088535553/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl2071758337/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3095234049/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3305145857/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2424210945/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl252151297/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1107461633/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2919400961/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl3321923073/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl3798500865/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3059975681/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3059975681/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3009644033/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl1517848065/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3624109569/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3209528833/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl1442940417/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1442940417/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2141815297/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl1807647233/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl826311425/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl716997121/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl4205937153/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl3433267713/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl4244997633/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl1182631425/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl2869659137/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2138867201/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl1908310529/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3490022913/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl1158252033/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2122089985/?ref_=bo_my_table_6', ...

# %%
#creating seperate for loops as suggested by Blair

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_element_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        movie_list = []
        link_list = []
        
        for year in ('2017','2018','2019','2020','2021','2022'):
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            monthly_box_office_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie = monthly_box_office_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            movie_list.append(movie)
        print(movie_list)


        for elements in movie_list:
            a_tag = .find_element(by=By.TAG_NAME, value='a')
            #link = a_tag.get_attribute('href')
            #link_list.append(link)

        #print(link_list)

            


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_element_links()
# Out:
# [[<selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="927cfbd9-02f6-47e4-a648-8177ff3a2b22")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="2c875b63-d5f2-432e-9a1a-c6665865440f")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="b8b13fd5-2c42-41e8-92c0-435769995b14")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="5a1f9a87-f7f2-4cf1-a749-0de8d59ef16e")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="5a71222e-6f7f-4cb8-bcf5-c3bff3d516e1")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="c750d246-eafe-4ee8-90c2-b18f05925734")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="e5c0048a-27e5-43dd-a106-c167d0cc5dae")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="0808de63-f292-489d-b3a4-ea67ce152db5")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="dbd39152-6187-4bca-92e7-bf1b623d8f16")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="cf7f2ece-05e5-4e46-a188-90d1a2ff571d")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="be5f6bb6-2bc1-44ad-a24f-1cb2f91a96f2")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="78b819ae-4319-4396-ae27-9a0ca82cab4b")>], [<selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="2a6d3339-1bc7-4b94-8ebc-39927c11584a")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="7a9a9855-e075-40fc-bbd8-fddfc4599063")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="48c085f0-0b77-4960-b86b-ae3239895e2d")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="6972cbc5-99a6-4a75-a386-c72adb9602a8")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="2bed4528-60e7-4405-8988-3c1240ded3fe")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="f78cc4b5-295a-4ed1-94d1-87ae72779286")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="5f66904a-4e00-4458-9a04-9986819a892c")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="cf9e4059-c40f-40bc-84af-715f25eaac2c")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="b4d9a655-6ff0-4fc2-8c40-74f6ae5814e2")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="1fbfe0eb-2887-4df6-87c2-80e31d7a3e29")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="edc7fb33-44ca-4914-a585-3a7a1c60f91a")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="97527b1b-7df1-447e-bc71-58a1022a290d")>], [<selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="56fe9456-e497-4e06-8677-18d541117626")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="1d2548cc-12b1-4adf-8a87-1c6b54bfeece")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="4ee46cd3-851b-440b-8f19-1aeba0ad5f97")>, <selenium.webdriver.remote.webelement.WebElement (session="afcb64cf47b5e62278fdb80c1e04d515", element="cdf ...

# %%
#Part one of seperating removing nested for loop: create movie list.

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.year_list = year_list

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def return_movie_list_by_year(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
        movie_tag = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
        movie_list = []
        
        time.sleep(3)

        for year in (self.year_list):
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)
            
            movie_list.append(movie_tag)
        
        print(movie_list)

        return movie_list
    
  
        


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    year_list = ['2017', '2018']
    imdb.return_movie_list_by_year()
# Out:
# [[<selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="952b1b0f-86c8-417e-a64f-2c2760fb9bea")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="0000a5d7-02ec-423e-bdbb-4d2eb2478567")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="e00ce0ba-8853-4fca-bec1-421be7fa808b")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="195f4670-69f9-4a55-88c5-7c0159173b37")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="a63109d1-a399-46df-bd7e-5f39f32ade03")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="fea72b97-f14a-4080-9068-99f20d610d55")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="0eef7169-874a-43d9-9266-d73482cc13ce")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="f115c3e8-370f-4a54-9db5-e2f6e5c7abd8")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="ba952c50-cbb4-475a-8c91-0dd7f87ec258")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="a36b394d-59b5-4272-95d2-0a9c92a31cc3")>], [<selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="952b1b0f-86c8-417e-a64f-2c2760fb9bea")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="0000a5d7-02ec-423e-bdbb-4d2eb2478567")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="e00ce0ba-8853-4fca-bec1-421be7fa808b")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="195f4670-69f9-4a55-88c5-7c0159173b37")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="a63109d1-a399-46df-bd7e-5f39f32ade03")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="fea72b97-f14a-4080-9068-99f20d610d55")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="0eef7169-874a-43d9-9266-d73482cc13ce")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="f115c3e8-370f-4a54-9db5-e2f6e5c7abd8")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="ba952c50-cbb4-475a-8c91-0dd7f87ec258")>, <selenium.webdriver.remote.webelement.WebElement (session="3ba84ed2f143d0bd49efd300666b6d1b", element="a36b394d-59b5-4272-95d2-0a9c92a31cc3")>]]

# %%
#Part one of seperating removing nested for loop: create movie list.

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.year_list = year_list

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def return_movie_list_by_year(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
        movie_tag = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
        movie_list = []
        link_list = []
        
        time.sleep(3)

        for year in (self.year_list):
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)           
            movie_list.extend(movie_tag)
        
        #print(movie_list)
    

        for movie_tag in movie_list:
            a_tag = movie_tag.find_element(by=By.TAG_NAME, value='a')
            link = a_tag.get_attribute('href')
            link_list.append(link)
            
        print(link_list)

        

    
        
    
  
        


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    year_list = ['2017', '2018']
    imdb.return_movie_list_by_year()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In [139], line 69
#      67 imdb.navigate_to_movie_table()
#      68 year_list = ['2017', '2018']
# ---> 69 imdb.return_movie_list_by_year()
#
# Cell In [139], line 50, in Scraper.return_movie_list_by_year(self)
#      46 #print(movie_list)
#      49 for movie_tag in movie_list:
# ---> 50     a_tag = movie_tag.find_element(by=By.TAG_NAME, value='a')
#      51     link = a_tag.get_attribute('href')
#      52     link_list.append(link)
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:419, in WebElement.find_element(self, by, value)
#     416     by = By.CSS_SELECTOR
#     417     value = '[name="%s"]' % value
# --> 419 return self._execute(Command.FIND_CHILD_ELEMENT,
#     420                      {"using": by, "value": value})['value']
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=106.0.5249.91)
# Stacktrace:
# 0   chromedriver 5                      0x0000000108b1f788 chromedriver 5 + 4515720
# 1   chromedriver 5                      0x0000000108aa39d3 chromedriver 5 + 4008403
# 2   chromedriver 5                      0x000000010873612a chromedriver 5 + 413994
# 3   chromedriver 5                      0x00000001087391b7 chromedriver 5 + 426423
# 4   chromedriver 5                      0x000000010873905f chromedriver 5 + 426079
# 5   chromedriver 5                      0x000000010873931c chromedriver 5 + 426780
# 6   chromedriver 5                      0x000000010876d587 chromedriver 5 + 640391
# 7   chromedriver 5                      0x000000010876da61 chromedriver 5 + 641633
# 8   chromedriver 5                      0x0000000108762137 chromedriver 5 + 594231
# 9   chromedriver 5                      0x000000010878a7fd chromedriver 5 + 759805
# 10  chromedriver 5                      0x0000000108762075 chromedriver 5 + 594037
# 11  chromedriver 5                      0x000000010878a92e chromedriver 5 + 760110
# 12  chromedriver 5                      0x000000010879dbd9 chromedriver 5 + 838617
# 13  chromedriver 5                      0x000000010878a603 chromedriver 5 + 759299
# 14  chromedriver 5                      0x0000000108760990 chromedriver 5 + 588176
# 15  chromedriver 5                      0x0000000108761a75 chromedriver 5 + 592501
# 16  chromedriver 5                      0x0000000108aef6cd chromedriver 5 + 4318925
# 17  chromedriver 5                      0x0000000108af3f35 chromedriver 5 + 4337461
# 18  chromedriver 5                      0x0000000108afb1ff chromedriver 5 + 4366847
# 19  chromedriver 5                      0x0000000108af4c5a chromedriver 5 + 4340826
# 20  chromedriver 5                      0x0000000108acac2c chromedriver 5 + 4168748
# 21  chromedriver 5                      0x0000000108b114f8 chromedriver 5 + 4457720
# 22  chromedriver 5                      0x0000000108b11693 chromedriver 5 + 4458131
# 23  chromedriver 5                      0x0000000108b26a3e chromedriver 5 + 4545086
# 24  libsystem_pthread.dylib             0x00007fff203b18fc _pthread_start + 224
# 25  libsystem_pthread.dylib             0x00007fff203ad443 thread_start + 15

# %%
#collecting src attributes for years 2017 and 2018

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        #link_list = []
        #image_list = []
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    def extract_image_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            src = img_tag.get_attribute('src')
            self.image_list.append(src)
            time.sleep(3)
        print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)






            

            



            


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.extract_image_data()
# Out:
# ['https://m.media-amazon.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BNzA1Njg4NzYxOV5BMl5BanBnXkFtZTgwODk5NjU3MzI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BZDVkZmI0YzAtNzdjYi00ZjhhLWE1ODEtMWMzMWMzNDA0NmQ4XkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SY139_CR0,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjA1MzIwMjMxNF5BMl5BanBnXkFtZTgwMDQ3NTc2MjI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BNTk4ODQ1MzgzNl5BMl5BanBnXkFtZTgwMTMyMzM4MTI@._V1_SX92_CR0,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMTYzODQzYjQtNTczNC00MzZhLTg1ZWYtZDUxYmQ3ZTY4NzA1XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BNjM0NTc0NzItM2FlYS00YzEwLWE0YmUtNTA2ZWIzODc2OTgxXkEyXkFqcGdeQXVyNTgwNzIyNzg@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjMxODI2NDM5Nl5BMl5BanBnXkFtZTgwNjgzOTk1MTI@._V1_SX92_CR0,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMTUwNjUxMTM4NV5BMl5BanBnXkFtZTgwODExMDQzMTI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMTcyNTEyOTY0M15BMl5BanBnXkFtZTgwOTAyNzU3MDI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjEwMzMxODIzOV5BMl5BanBnXkFtZTgwNzg3OTAzMDI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BOTk5ODg0OTU5M15BMl5BanBnXkFtZTgwMDQ3MDY3NjM@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BYmE5Yjg0MzktYzgzMi00YTFiLWJjYTItY2M5MmI1ODI4MDY3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX92_CR0,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BNTFkZjdjN2QtOGE5MS00ZTgzLTgxZjAtYzkyZWQ5MjEzYmZjXkEyXkFqcGdeQXVyMTM0NTUzNDIy._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjM3NzQ5NDcxOF5BMl5BanBnXkFtZTgwNzM4MTQ5NTM@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BNjRlZmM0ODktY2RjNS00ZDdjLWJhZGYtNDljNWZkMGM5MTg0XkEyXkFqcGdeQXVyNjAwMjI5MDk@._V1_SX92_CR0,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BYjcyYTk0N2YtMzc4ZC00Y2E0LWFkNDgtNjE1MzZmMGE1YjY1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMTEzNzY0OTg0NTdeQTJeQWpwZ15BbWU4MDU3OTg3MjUz._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SY139_CR1,0,92,139_.jpg', 'https://m.media-amazon.com/images/M/MV5BODQ0NDhjYWItYTMxZi00NTk2LWIzNDEtOWZiYWYxZjc2MTgxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY139_CR1,0,92,139_.jpg']

# %%
#storing image data and text data in two seperate methods for years 2017 and 2018

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        #link_list = []
        #image_list = []
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_gross_value = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[1]/div/div[3]/span[2]/a/span').text
            print(worldwide_gross_value)
            # NEEDS WORK - distributor = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[1]/span[2]').text
            #print(distributor)
            opening_gross_value = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[2]/span[2]/span').text
            print(opening_gross_value)
            #NEEDS WORK -opening_number_of_theatres = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[2]/span[2]').text
            #print(opening_number_of_theatres)
            budget_value = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[3]/span[2]/span').text
            print(budget_value)
            start_release_date = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[4]/span[2]/a[1]').text
            print(start_release_date)
            end_release_date = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[4]/span[2]/a[2]').text
            print(end_release_date)
            running_time = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[6]/span[2]').text
            print(running_time)
            genre = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[7]/span[2]').text
            print(genre)
            total_release_time_period = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[8]/span[2]').text
            print(total_release_time_period)
            widest_theatre_release = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/main/div/div[3]/div[4]/div[9]/span[2]').text
            print(widest_theatre_release)
            #time.sleep(1)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()

# %%
#collecting image data and text data in two seperate methods for years 2017 and 2018

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_of_movie_information = {}
        

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        #link_list = []
        #image_list = []
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #self.dictionary_of_movie_information = {'Gross value': [], 'Opening gross value': [], 'Budget value': [], 'Start release date': [], 'End release date': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
            
            worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            print(worldwide_gross_value)
            distributor = summary_values.find_element(by=By.XPATH, value='div[1]/span[2]').text
            print(distributor)
            opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            print(opening_gross_value)
            budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
            print(budget_value)
            start_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            print(start_release_date)
            end_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[2]').text
            print(end_release_date)
            movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            print(movie_run_time)
            genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            print(genre)
            total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            print(total_release_time)
            number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
            print(number_of_theatre_releases)
            time.sleep(1)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()

# %%
#collecting text data and storing information in a dictionary

from curses import start_color
from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.common.exceptions import NoSuchElementException

import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
        
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2020'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Start release date': [], 'End release date': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
            
            worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_of_movie_information['Gross value'].append(worldwide_gross_value)
            
            distributor = summary_values.find_element(by=By.XPATH, value='div[1]/span[2]').text
            self.dictionary_of_movie_information['Distributor'].append(distributor)
            
            opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            self.dictionary_of_movie_information['Opening gross value'].append(opening_gross_value)
             
            try:
                budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
                self.dictionary_of_movie_information['Budget value'].append(budget_value)
            
            except NoSuchElementException:
                pass

            
            #start_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            #self.dictionary_of_movie_information['Start release date'].append(start_release_date)
            
            #end_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[2]').text
            #self.dictionary_of_movie_information['End release date'].append(end_release_date)
            
            movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            self.dictionary_of_movie_information['Movie runtime'].append(movie_run_time)
            
            genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            self.dictionary_of_movie_information['Genre'].append(genre)
            
            total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            self.dictionary_of_movie_information['Total release time'].append(total_release_time)
            
            try:
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except AttributeError: 
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except:
                pass
            
            


        
            
            time.sleep(1)
        
        print(self.dictionary_of_movie_information)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()
# Out:
# {'Gross value': ['$1,332,539,889', '$853,977,126', '$259,239,658', '$700,381,748', '$306,515,884', '$880,166,924', '$821,847,012', '$863,756,051', '$1,236,005,118', '$1,263,521,126', '$311,950,384', '$1,056,057,273', '$169,602,006', '$215,905,815', '$365,294,355', '$365,294,355', '$44,331,465', '$2,902,552', '$1,045,873', '$4,369,493', '$23,613', '$141,940,042', '$319,715,683', '$426,505,244'], 'Distributor': ['Walt Disney Studios Motion Pictures\nSee full company information', 'Walt Disney Studios Motion Pictures\nSee full company information', 'Warner Bros.\nSee full company information', 'Warner Bros.\nSee full company information', 'Warner Bros.\nSee full company information', 'Sony Pictures Entertainment (SPE)\nSee full company information', 'Warner Bros.\nSee full company information', 'Walt Disney Studios Motion Pictures\nSee full company information', 'Universal Pictures\nSee full company information', 'Walt Disney Studios Motion Pictures\nSee full company information', 'Warner Bros.\nSee full company information', 'Walt Disney Studios Motion Pictures\nSee full company information', 'Warner Bros.\nSee full company information', 'Universal Pictures\nSee full company information', 'Warner Bros.\nSee full company information', 'Warner Bros.\nSee full company information', 'Solstice Studios\nSee full company information', 'IFC Films\nSee full company information', 'Quiver Distribution\nSee full company information', 'IFC Films\nSee full company information', 'Aspiration Entertainment\nSee full company information', 'Walt Disney Studios Motion Pictures\nSee full company information', 'Paramount Pictures\nSee full company information', 'Sony Pictures Entertainment (SPE)\nSee full company information'], 'Opening gross value': ['$220,009,584', '$122,744,989', '$32,753,122', '$123,403,419', '$35,006,404', '$117,027,503', '$103,251,471', '$146,510,104', '$98,786,705', '$174,750,616', '$53,003,468', '$155,081,681', '$16,701,957', '$9,724,200', '$9,353,090', '$9,353,090', '$601,032', '$192,352', '$209,394', '$65,908', '$3,842', '$39,119,861', '$58,018,348', '$62,504,105'], 'Budget value': ['$317,000,000', '$180,000,000', '$150,000,000', '$35,000,000', '$15,000,000', '$175,000,000', '$149,000,000', '$200,000,000', '$250,000,000', '$160,000,000', '$80,000,000', '$200,000,000', '$85,000,000', '$90,000,000'], 'Movie runtime': ['2 hr 32 min', '2 hr 10 min', '2 hr 44 min', '2 hr 15 min', '1 hr 49 min', '2 hr 13 min', '2 hr 21 min', '2 hr 16 min', '2 hr 16 min', '2 hr 9 min', '1 hr 44 min', '2 hr 13 min', 'Action Adventure Fantasy', 'Adventure Animation Comedy Family Fantasy', 'Action Sci-Fi Thriller', 'Action Sci-Fi Thriller', 'Action Thriller', 'Drama Horror Mystery Thriller', 'Action Crime Drama Horror Thriller', '245 days/35 weeks', 'Comedy', 'Adventure Animation Comedy Family Fantasy', '1 hr 39 min', '2 hr 4 min'], 'Genre': ['Action Adventure Fantasy Sci-Fi', 'Action Adventure Comedy Fantasy Sci-Fi', 'Action Drama Mystery Sci-Fi Thriller', 'Horror', 'Horror Mystery Thriller', 'Action Adventure Sci-Fi', 'Action Adventure Fantasy Sci-Fi War', 'Action Adventure Comedy Sci-Fi', 'Action Crime Thriller', 'Adventure Family Fantasy Musical Romance', 'Action Adventure Animation Comedy Family Fantasy Sci-Fi', 'Action Adventure Sci-Fi', '660 days/94 weeks', '402 days/57 weeks', '773 days/110 weeks', '773 days/110 weeks', '147 days/21 weeks', '182 days/26 weeks', '210 days/30 weeks', '101 theaters', '287 days/41 weeks', '301 days/43 weeks', 'Action Adventure Comedy Family Fantasy Sci-Fi', 'Action Comedy Crime Thriller'], 'Total release time': ['382 days/54 weeks', '424 days/60 weeks', '452 days/64 weeks', '119 days/17 weeks', '143 days/20 weeks', '182 days/26 weeks', '217 days/31 weeks', '241 days/34 weeks', '262 days/37 weeks', '290 days/41 weeks', '325 days/46 weeks', '381 days/54 weeks', '2,218 theaters', '2,211 theaters', '2,930 theaters', '2,930 theaters', '2,402 theaters', '133 theaters', '54 theaters', 'See more details at IMDbPro', '33  ...

# %%
#collecting text data and storing information in a dictionary - MODIFYING DIV TAGS

from curses import start_color
from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.common.exceptions import NoSuchElementException

import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
        
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2020'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            summary_values_by_row = summary_values.fund_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Start release date': [], 'End release date': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
            
            worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_of_movie_information['Gross value'].append(worldwide_gross_value)
            
            distributor = summary_values.find_element(by=By.XPATH, value='div[1]/span[2]').text
            self.dictionary_of_movie_information['Distributor'].append(distributor)
            
            opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            self.dictionary_of_movie_information['Opening gross value'].append(opening_gross_value)
             
            try:
                budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
                self.dictionary_of_movie_information['Budget value'].append(budget_value)
            
            except NoSuchElementException:
                pass

            
            start_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            self.dictionary_of_movie_information['Start release date'].append(start_release_date)
            
            end_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[2]').text
            self.dictionary_of_movie_information['End release date'].append(end_release_date)
            
            movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            self.dictionary_of_movie_information['Movie runtime'].append(movie_run_time)
            
            genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            self.dictionary_of_movie_information['Genre'].append(genre)
            
            total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            self.dictionary_of_movie_information['Total release time'].append(total_release_time)
            
            try:
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except AttributeError: 
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except:
                pass
            
            


        
            
            time.sleep(1)
        
        print(self.dictionary_of_movie_information)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()

# %%
#refactoring code to extract data for one movie

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list[0:1]:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            print(div_tags)
            print(len(div_tags))
            
            #performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            #worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            #print(worldwide_gross_value)
            #print(opening_gross_value)
            #opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            #budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
            #print(budget_value)
            #release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            #print(release_date)
            #movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            #print(movie_run_time)
            #genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            #print(genre)
            #total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            #print(total_release_time)
            #number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
            #print(number_of_theatre_releases)
            #time.sleep(1)

            
           

           




if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="ebbb299f-7f43-476b-9c6d-d1f9f11ec85f")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="39eda1a9-f2f8-4f38-8071-c9ad548d4b9e")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="acb33254-a2a9-4aa3-98c2-ef9169918a15")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="84c23d69-6c0f-46ac-957b-3924505ed466")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="aaf35c33-cf13-4cad-b182-125620ada9b7")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="81fc52ac-1aa0-4c9d-b1b6-dc07ae6a8d47")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="81c4a868-3d03-4819-9c9f-8f7f4d4a9dd7")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="85563c0d-7329-4266-83f4-ea468c848f0e")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="012d500a-7b01-4eca-a23f-7f80fb6902b7")>, <selenium.webdriver.remote.webelement.WebElement (session="ed7de11587ceb524895231340b6fb3a2", element="484fb676-d106-48bf-b323-961a62b866bb")>]
# 10

# %%
my_list = ['John', 'Paul', 'George', 'Ringo']
my_list.append(['Lennon','McCartney','Harrison', 'Starr'])

print(my_list)
# Out:
# ['John', 'Paul', 'George', 'Ringo', ['Lennon', 'McCartney', 'Harrison', 'Starr']]

# %%
my_list = ['John', 'Paul', 'George', 'Ringo']
last_item = my_list.pop()
last_item
# Out:
# 'Ringo'

# %%
list_of_strings = ["This", "is", "a", "sentence."]

print("    Random String    ".join(list_of_strings))
# Out:
# This    Random String    is    Random String    a    Random String    sentence.

# %%
#refactoring code to extract data for one movie and storing as key value pairs in a dictionary

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.movie_dictionary = {}
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list[0:1]:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            #print(div_tags)
            #print(len(div_tags))

            for text in div_tags:
                key = div_tags.find_element(by=By.XPATH, value='span[1]').text
                value = div_tags.find_element(by=By.XPATH, value='span[2]').text
                self.movie_dictionary.update({key:value})
                print(self.movie_dictionary)
                print(len(self.movie_dictionary))







            #TESTING ADDING KEY VALUE PAIRS TO DICTIONARIES
            #movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            #genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            #self.movie_dictionary.update({movie_run_time:genre})
            #print(self.movie_dictionary)
            #print(len(self.movie_dictionary))


        
            #key = div_tags.find_element(by=By.XPATH, value='span[1]').text
            #value = div_tags.find_element(by=By.XPATH, value='span[2]').text
            #self.movie_dictionary.update({key:value})
            #print(self.movie_dictionary)
            #print(len(self.movie_dictionary))


            
            #performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            #worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            #print(worldwide_gross_value)
            #print(opening_gross_value)
            #opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            #budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
            #print(budget_value)
            #release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            #print(release_date)
            #movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            #print(movie_run_time)
            #genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            #print(genre)
            #total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            #print(total_release_time)
            #number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
            #print(number_of_theatre_releases)
            #time.sleep(1)

            
           

           




if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [72], line 138
#     136 imdb.get_movie_links()
#     137 #imdb.extract_image_data()
# --> 138 imdb.extract_text_data()
#
# Cell In [72], line 76, in Scraper.extract_text_data(self)
#      72 #print(div_tags)
#      73 #print(len(div_tags))
#      75 for text in div_tags:
# ---> 76     key = div_tags.find_element(by=By.XPATH, value='span[1]').text
#      77     value = div_tags.find_element(by=By.XPATH, value='span[2]').text
#      78     print(self.movie_dictionary)
#
# AttributeError: 'list' object has no attribute 'find_element'

# %%
#Original code

from curses import start_color
from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.common.exceptions import NoSuchElementException

import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
        
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2020'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            summary_values_by_row = summary_values.fund_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Start release date': [], 'End release date': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
            
            worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_of_movie_information['Gross value'].append(worldwide_gross_value)
            
            distributor = summary_values.find_element(by=By.XPATH, value='div[1]/span[2]').text
            self.dictionary_of_movie_information['Distributor'].append(distributor)
            
            opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            self.dictionary_of_movie_information['Opening gross value'].append(opening_gross_value)
             
            try:
                budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
                self.dictionary_of_movie_information['Budget value'].append(budget_value)
            
            except NoSuchElementException:
                pass

            
            start_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            self.dictionary_of_movie_information['Start release date'].append(start_release_date)
            
            end_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[2]').text
            self.dictionary_of_movie_information['End release date'].append(end_release_date)
            
            movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            self.dictionary_of_movie_information['Movie runtime'].append(movie_run_time)
            
            genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            self.dictionary_of_movie_information['Genre'].append(genre)
            
            total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            self.dictionary_of_movie_information['Total release time'].append(total_release_time)
            
            try:
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except AttributeError: 
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except:
                pass
            
        
            time.sleep(1)
        
        print(self.dictionary_of_movie_information)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()

# %%
#refactoring code to extract data for one movie and storing as key value pairs in a dictionary

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_for_text_data = {}
        self.movie_and_text_dictionary = {}
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list[0:1]:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            #print(div_tags)
            #print(len(div_tags))

            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.movie_dictionary.update({worldwide:international_gross})
            
            print(self.dictionary_for_text_data)
            print(len(self.dictionary_for_text_data))

            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.dictionary_for_text_data.update({key:value})
            
            print(self.movie_dictionary)
            print(len(self.movie_dictionary))

            
            

            

        
           
            
            #worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            #print(worldwide_gross_value)
            #print(opening_gross_value)
            #opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            #budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
            #print(budget_value)
            #release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            #print(release_date)
            #movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            #print(movie_run_time)
            #genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            #print(genre)
            #total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            #print(total_release_time)
            #number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
            #print(number_of_theatre_releases)
            #time.sleep(1)

            
           

           




if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()
# Out:
# {'WORLDWIDE': '$1,332,539,889'}
# 1
# {'WORLDWIDE': '$1,332,539,889', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$220,009,584\n4,232 theaters', 'Budget': '$317,000,000', 'Release Date': 'Dec 15, 2017 - Apr 19, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 32 min', 'Genres': 'Action Adventure Fantasy Sci-Fi', 'In Release': '382 days/54 weeks', 'Widest Release': '4,232 theaters', 'IMDbPro': 'See more details at IMDbPro'}
# 11

# %%
#refactoring code to extract data for one movie and storing as key value pairs in a dictionary

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import uuid


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_for_text_data = {}
        self.movie_and_text_dictionary = {}
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def locate_text_data(self):
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
         
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_for_text_data.update({worldwide:international_gross})

            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.dictionary_for_text_data.update({key:value})
            
            #print(self.dictionary_for_text_data)
            #print(len(self.dictionary_for_text_data))
            time.sleep(1)

    def extract_text_data(self):
        for link in self.link_list[0:10]:
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            #print(movie_name)
            Scraper.locate_text_data(self)
            self.movie_and_text_dictionary.update({movie_name:self.dictionary_for_text_data})
            
        print(self.movie_and_text_dictionary)







if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()
# Out:
# {'Star Wars: Episode VIII - The Last Jedi': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Thor: Ragnarok': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Blade Runner 2049': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'It': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Annabelle: Creation': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Spider-Man: Homecoming': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Wonder Woman': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Guardians of the Galaxy Vol. 2': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', 'MPAA': 'PG', 'Running Time': '2 hr 9 min', 'Genres': 'Adventure Family Fantasy Musical Romance', 'In Release': '290 days/41 weeks', 'Widest Release': '4,210 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'The Fate of the Furious': {'WORLDWIDE': '$1,263,521,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$174,750,616\n4,210 theaters', 'Budget': '$160,000,000', 'Release Date': 'Mar 17, 2017 - Jul 13, 2017', ' ...

# %%
#refactoring code to extract data for one movie and storing as key value pairs in a dictionary

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import uuid


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_for_text_data = {}
        self.movie_and_text_dictionary = {}
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def locate_text_data(self):
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
         
            
            movie_uuid_name = 'UUID'
            movie_uuid = uuid.uuid4()
            self.dictionary_for_text_data.update({movie_uuid_name:movie_uuid})
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_for_text_data.update({worldwide:international_gross})
            

            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.dictionary_for_text_data.update({key:value})
            
            time.sleep(1)

    def extract_text_data(self):
        for link in self.link_list[0:4]:
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            Scraper.locate_text_data(self)
            self.movie_and_text_dictionary.update({movie_name:self.dictionary_for_text_data})
            
            
        print(self.movie_and_text_dictionary)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()
# Out:
# {'Star Wars: Episode VIII - The Last Jedi': {'UUID': UUID('78ea1047-304e-4d6f-9195-9892d82e0135'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Thor: Ragnarok': {'UUID': UUID('78ea1047-304e-4d6f-9195-9892d82e0135'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Blade Runner 2049': {'UUID': UUID('78ea1047-304e-4d6f-9195-9892d82e0135'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'It': {'UUID': UUID('78ea1047-304e-4d6f-9195-9892d82e0135'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro'}}

# %%
#Original code

from curses import start_color
from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.common.exceptions import NoSuchElementException

import time


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
        
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2020'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    #def extract_image_data(self):
        #for link in self.link_list:
            #self.driver.get(link)
            #time.sleep(3)
            #image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            #img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            #src = img_tag.get_attribute('src')
            #self.image_list.append(src)
            #time.sleep(3)
        #print(self.image_list)

    def extract_text_data(self):
        for link in self.link_list:
            self.driver.get(link)
            time.sleep(3)
            
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            summary_values_by_row = summary_values.fund_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            #self.dictionary_of_movie_information = {'Gross value': [], 'Distributor': [], 'Opening gross value': [], 'Budget value': [], 'Start release date': [], 'End release date': [], 'Movie runtime': [], 'Genre': [], 'Total release time': [], 'Number of theatre releases': []}
            
            worldwide_gross_value = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_of_movie_information['Gross value'].append(worldwide_gross_value)
            
            distributor = summary_values.find_element(by=By.XPATH, value='div[1]/span[2]').text
            self.dictionary_of_movie_information['Distributor'].append(distributor)
            
            opening_gross_value = summary_values.find_element(by=By.XPATH, value='div[2]/span[2]/span').text
            self.dictionary_of_movie_information['Opening gross value'].append(opening_gross_value)
             
            try:
                budget_value = summary_values.find_element(by=By.XPATH, value='div[3]/span[2]/span').text
                self.dictionary_of_movie_information['Budget value'].append(budget_value)
            
            except NoSuchElementException:
                pass

            
            start_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[1]').text
            self.dictionary_of_movie_information['Start release date'].append(start_release_date)
            
            end_release_date = summary_values.find_element(by=By.XPATH, value='div[4]/span[2]/a[2]').text
            self.dictionary_of_movie_information['End release date'].append(end_release_date)
            
            movie_run_time = summary_values.find_element(by=By.XPATH, value='div[6]/span[2]').text
            self.dictionary_of_movie_information['Movie runtime'].append(movie_run_time)
            
            genre = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
            self.dictionary_of_movie_information['Genre'].append(genre)
            
            total_release_time = summary_values.find_element(by=By.XPATH, value='div[8]/span[2]').text
            self.dictionary_of_movie_information['Total release time'].append(total_release_time)
            
            try:
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[9]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except AttributeError: 
                number_of_theatre_releases = summary_values.find_element(by=By.XPATH, value='div[7]/span[2]').text
                self.dictionary_of_movie_information['Number of theatre releases'].append(number_of_theatre_releases)
            
            except:
                pass
            
        
            time.sleep(1)
        
        print(self.dictionary_of_movie_information)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    #imdb.extract_image_data()
    imdb.extract_text_data()

# %%
#Milestone 3, Task 4: Extract data and store in a dictionary which maps feature name to feature value - COMPLETED.

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import uuid


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.image_list = []
        self.dictionary_for_text_data = {}
        self.movie_and_text_dictionary = {}
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(5)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)
   

    def extract_image_data(self):
            image_name = 'image_file'
            image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
            img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
            src = img_tag.get_attribute('src')
            self.dictionary_for_text_data.update({image_name:src})
           

    def locate_text_data(self):
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
         
            
            movie_uuid_name = 'UUID'
            movie_uuid = uuid.uuid4()
            self.dictionary_for_text_data.update({movie_uuid_name:movie_uuid})
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.dictionary_for_text_data.update({worldwide:international_gross})
            

            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.dictionary_for_text_data.update({key:value})
            
            time.sleep(1)

    def extract_text_data(self):
        for link in self.link_list[0:4]:
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            Scraper.locate_text_data(self)
            self.movie_and_text_dictionary.update({movie_name:self.dictionary_for_text_data})
            Scraper.extract_image_data(self)
            
            
        #print(self.movie_and_text_dictionary)



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.extract_text_data()
# Out:
# {'Star Wars: Episode VIII - The Last Jedi': {'UUID': UUID('a3c311b7-f0ff-4d51-b0bc-6bf9e84547d6'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_file': 'https://m.media-amazon.com/images/M/MV5BZDVkZmI0YzAtNzdjYi00ZjhhLWE1ODEtMWMzMWMzNDA0NmQ4XkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SY139_CR0,0,92,139_.jpg'}, 'Thor: Ragnarok': {'UUID': UUID('a3c311b7-f0ff-4d51-b0bc-6bf9e84547d6'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_file': 'https://m.media-amazon.com/images/M/MV5BZDVkZmI0YzAtNzdjYi00ZjhhLWE1ODEtMWMzMWMzNDA0NmQ4XkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SY139_CR0,0,92,139_.jpg'}, 'Blade Runner 2049': {'UUID': UUID('a3c311b7-f0ff-4d51-b0bc-6bf9e84547d6'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_file': 'https://m.media-amazon.com/images/M/MV5BZDVkZmI0YzAtNzdjYi00ZjhhLWE1ODEtMWMzMWMzNDA0NmQ4XkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SY139_CR0,0,92,139_.jpg'}, 'It': {'UUID': UUID('a3c311b7-f0ff-4d51-b0bc-6bf9e84547d6'), 'WORLDWIDE': '$700,381,748', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$123,403,419\n4,103 theaters', 'Budget': '$35,000,000', 'Release Date': 'Sep 8, 2017 - Dec 14, 2017', 'MPAA': 'R', 'Running Time': '2 hr 15 min', 'Genres': 'Horror', 'In Release': '119 days/17 weeks', 'Widest Release': '4,148 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_file': 'https://m.media-amazon.com/images/M/MV5BZDVkZmI0YzAtNzdjYi00ZjhhLWE1ODEtMWMzMWMzNDA0NmQ4XkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SY139_CR0,0,92,139_.jpg'}}

# %%
#Milestone 3, Task 2: Creating key_value dictionary - COMPLETED

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import uuid


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        # self.key_list = []
        # self.value_list = []
        # self.key_value_list = zip(self.key_list, self.value_list)
        self.data_dictionary = {}
        self.movie_id_and_data_dictionary = {}
        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)


    def locate_text_data(self):
        key_list = []
        value_list = []
        key_value_list = []

        for link in self.link_list[0:3]:
            self.driver.get(link)
            time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.data_dictionary.update({worldwide:international_gross})

            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                key_list.append(key)
                value = text.find_element(by=By.XPATH, value='span[2]').text
                value_list.append(value)
    
        key_value_dictionary = dict(zip(key_list, value_list))
        print(key_value_dictionary)

       



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.locate_text_data()
# Out:
# {'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$32,753,122\n4,058 theaters', 'Budget': '$150,000,000', 'Release Date': 'Oct 6, 2017 - Feb 1, 2018', 'MPAA': 'R', 'Running Time': '2 hr 44 min', 'Genres': 'Action Drama Mystery Sci-Fi Thriller', 'In Release': '452 days/64 weeks', 'Widest Release': '4,058 theaters', 'IMDbPro': 'See more details at IMDbPro'}

# %%
#Milestone 3, Task 2: Creating key_value dictionary to include worldwide gross - COMPLETED

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import uuid


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        # self.key_list = []
        # self.value_list = []
        # self.key_value_list = zip(self.key_list, self.value_list)
        self.data_dictionary = {}
        self.movie_id_and_data_dictionary = {}
        self.key_list = []
        self.value_list = []
        self.key_value_dictionary = {}

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)


    def locate_text_data(self):
        for link in self.link_list[0:3]:
            self.driver.get(link)
            time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.key_list.append(worldwide)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.value_list.append(international_gross)
            
            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                self.key_list.append(key)
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.value_list.append(value)
              
            self.key_value_dictionary = dict(zip(self.key_list, self.value_list))
            print(self.key_value_dictionary)
            return self.key_value_dictionary

     



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.locate_text_data()
# Out:
# {'WORLDWIDE': '$1,332,539,889', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$220,009,584\n4,232 theaters', 'Budget': '$317,000,000', 'Release Date': 'Dec 15, 2017 - Apr 19, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 32 min', 'Genres': 'Action Adventure Fantasy Sci-Fi', 'In Release': '382 days/54 weeks', 'Widest Release': '4,232 theaters', 'IMDbPro': 'See more details at IMDbPro'}
# {'WORLDWIDE': '$853,977,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$122,744,989\n4,080 theaters', 'Budget': '$180,000,000', 'Release Date': 'Nov 3, 2017 - Mar 15, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 10 min', 'Genres': 'Action Adventure Comedy Fantasy Sci-Fi', 'In Release': '424 days/60 weeks', 'Widest Release': '4,080 theaters', 'IMDbPro': 'See more details at IMDbPro'}
# {'WORLDWIDE': '$259,239,658', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$32,753,122\n4,058 theaters', 'Budget': '$150,000,000', 'Release Date': 'Oct 6, 2017 - Feb 1, 2018', 'MPAA': 'R', 'Running Time': '2 hr 44 min', 'Genres': 'Action Drama Mystery Sci-Fi Thriller', 'In Release': '452 days/64 weeks', 'Widest Release': '4,058 theaters', 'IMDbPro': 'See more details at IMDbPro'}

# %%
#Milestone 3, Task 2: Creating key_value dictionary to include worldwide gross, movie ID, image file & timestamp - COMPLETED.

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime



class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.key_list = []
        self.value_list = []
        self.key_value_dictionary = {}
        self.movie_dictionary = {}

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)


    def locate_text_data(self):
        # for link in self.link_list[0:3]:
        #     self.driver.get(link)
        #     time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.key_list.append(worldwide)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.value_list.append(international_gross)
            
            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                self.key_list.append(key)
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.value_list.append(value)
              
            self.key_value_dictionary = dict(zip(self.key_list, self.value_list))
            #print(self.key_value_dictionary)
            return self.key_value_dictionary

    def extract_text_data(self):
        for link in self.link_list[0:3]:
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            Scraper.timestamp(self)
            Scraper.extract_image_data(self)
            Scraper.locate_text_data(self)
            self.movie_dictionary.update({movie_name:self.key_value_dictionary})
        print(self.movie_dictionary)

    def timestamp(self):        
        time_key = 'date_time_of_webscrape'
        self.key_list.append(time_key)
        timestamp = 'Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
        self.value_list.append(timestamp)

    def extract_image_data(self):
        image_name = 'image_file'
        self.key_list.append(image_name)
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        self.value_list.append(src)
        
        
        
     



if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.extract_text_data()
# Out:
# {'Star Wars: Episode VIII - The Last Jedi': {'date_time_of_webscrape': 'Timestamp: 2022-10-21 17:29:39', 'image_file': 'https://m.media-amazon.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_SY139_CR1,0,92,139_.jpg', 'WORLDWIDE': '$1,332,539,889', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$220,009,584\n4,232 theaters', 'Budget': '$317,000,000', 'Release Date': 'Dec 15, 2017 - Apr 19, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 32 min', 'Genres': 'Action Adventure Fantasy Sci-Fi', 'In Release': '382 days/54 weeks', 'Widest Release': '4,232 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Thor: Ragnarok': {'date_time_of_webscrape': 'Timestamp: 2022-10-21 17:29:43', 'image_file': 'https://m.media-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_SY139_CR1,0,92,139_.jpg', 'WORLDWIDE': '$853,977,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$122,744,989\n4,080 theaters', 'Budget': '$180,000,000', 'Release Date': 'Nov 3, 2017 - Mar 15, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 10 min', 'Genres': 'Action Adventure Comedy Fantasy Sci-Fi', 'In Release': '424 days/60 weeks', 'Widest Release': '4,080 theaters', 'IMDbPro': 'See more details at IMDbPro'}, 'Blade Runner 2049': {'date_time_of_webscrape': 'Timestamp: 2022-10-21 17:29:47', 'image_file': 'https://m.media-amazon.com/images/M/MV5BNzA1Njg4NzYxOV5BMl5BanBnXkFtZTgwODk5NjU3MzI@._V1_SY139_CR1,0,92,139_.jpg', 'WORLDWIDE': '$259,239,658', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$32,753,122\n4,058 theaters', 'Budget': '$150,000,000', 'Release Date': 'Oct 6, 2017 - Feb 1, 2018', 'MPAA': 'R', 'Running Time': '2 hr 44 min', 'Genres': 'Action Drama Mystery Sci-Fi Thriller', 'In Release': '452 days/64 weeks', 'Widest Release': '4,058 theaters', 'IMDbPro': 'See more details at IMDbPro'}}

# %%
#Milestone 3, Task 3 - convert self.movie_dictionary to JSON file and programatically store in a folder within a folder in root path of project.


from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os



class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.key_list = []
        self.value_list = []
        self.key_value_dictionary = {}
        self.movie_dictionary = {}

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)


    def locate_text_data(self):
        # for link in self.link_list[0:3]:
        #     self.driver.get(link)
        #     time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.key_list.append(worldwide)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.value_list.append(international_gross)
            
            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                self.key_list.append(key)
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.value_list.append(value)
              
            self.key_value_dictionary = dict(zip(self.key_list, self.value_list))
            #print(self.key_value_dictionary)
            return self.key_value_dictionary

    def extract_text_data(self):
        for link in self.link_list[0:3]:
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            Scraper.timestamp(self)
            Scraper.extract_image_data(self)
            Scraper.locate_text_data(self)
            self.movie_dictionary.update({movie_name:self.key_value_dictionary})
        print(self.movie_dictionary)

    def timestamp(self):        
        time_key = 'date_time_of_webscrape'
        self.key_list.append(time_key)
        timestamp = 'Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
        self.value_list.append(timestamp)

    def extract_image_data(self):
        image_name = 'image_file'
        self.key_list.append(image_name)
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        self.value_list.append(src)

    def download_data(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        

   


if __name__ == '__main__':
    imdb = Scraper()
    # imdb.navigate_to_movie_table()
    # imdb.get_movie_links()
    # imdb.extract_text_data()
    imdb.download_data()

# %%
#Milestone 4, Task 4 - Create a method to find image links and download images.

from operator import index
from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests



class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.key_list = []
        self.value_list = []
        self.key_value_dictionary = {}
        self.movie_dictionary = {}

        time.sleep(3)

    def navigate_to_movie_table(self):
        page_body = self.driver.find_element(by=By.XPATH, value='/html/body/div[1]/div[3]')
        mojo_tab_container = page_body.find_element(by=By.XPATH, value='div[3]/div')
        monthly_button = mojo_tab_container.find_element(by=By.XPATH, value='//a[@href="/month/?ref_=bo_nb_hm_secondarytab"]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)


    def locate_text_data(self):
        # for link in self.link_list[0:3]:
        #     self.driver.get(link)
        #     time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.key_list.append(worldwide)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.value_list.append(international_gross)
            
            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                self.key_list.append(key)
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.value_list.append(value)
              
            self.key_value_dictionary = dict(zip(self.key_list, self.value_list))
            #print(self.key_value_dictionary)
            return self.key_value_dictionary

    def extract_text_data(self):
        for link in self.link_list[0:3]:
            self.driver.get(link)
            time.sleep(2)
            #div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            #movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            #Scraper.timestamp(self)
            Scraper.extract_image_data(self)
            #Scraper.locate_text_data(self)
            #self.movie_dictionary.update({movie_name:self.key_value_dictionary})
        #print(self.movie_dictionary)

    def timestamp(self):        
        time_key = 'date_time_of_webscrape'
        self.key_list.append(time_key)
        timestamp = 'Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
        self.value_list.append(timestamp)

    def extract_image_data(self, url: str ="https://www.boxofficemojo.com/"):
        image_name = 'image_file'
        #self.key_list.append(image_name)
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        #self.value_list.append(src)
        timestr = time.strftime("%Y%m%d_%H%M%S")

        Scraper.download_image(src, f'raw_data/box_office_mojo/images/{timestr}_.jpg')
        
        
    def download_image(image_url, fp):
        img_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(img_data)

      

    def download_data(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
        
   


        

   


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.download_data()
    imdb.extract_text_data()

# %%
#Milestone 4, Task 4 - Change filename of downloaded image to include date, time and order of image - work with Ivan

from operator import index
from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests



class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Users/apple/Documents/GitHub/DC_Zoopla/chromedriver 5' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.link_list = []
        self.key_list = []
        self.value_list = []
        self.key_value_dictionary = {}
        self.movie_dictionary = {}

        time.sleep(3)

    def navigate_to_movie_table(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def get_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.link_list.append(link)

        return(self.link_list)


    def locate_text_data(self):
        # for link in self.link_list[0:3]:
        #     self.driver.get(link)
        #     time.sleep(3)
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.key_list.append(worldwide)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.value_list.append(international_gross)
            
            for text in div_tags:
                key = text.find_element(by=By.XPATH, value='span[1]').text
                self.key_list.append(key)
                value = text.find_element(by=By.XPATH, value='span[2]').text
                self.value_list.append(value)
              
            key_value_dictionary = dict(zip(self.key_list, self.value_list))
            #print(self.key_value_dictionary)
            return key_value_dictionary

    def extract_text_data(self):
        for n, link in enumerate(self.link_list[0:3], 1):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            #Scraper.timestamp(self)
            image_link = self.extract_image_data(n)
            new_dictionary = self.locate_text_data()
            new_dictionary.update({'image_link': image_link})

            self.movie_dictionary.update({movie_name:new_dictionary})
        print(self.movie_dictionary)

        
    def timestamp(self):        
        time_key = 'date_time_of_webscrape'
        self.key_list.append(time_key)
        timestamp = 'Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
        self.value_list.append(timestamp)

    def extract_image_data(self, n):
        image_name = 'image_file'
        #self.key_list.append(image_name)
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src

        #self.value_list.append(src)
        #timestr = time.strftime("%Y%m%d_%H%M%S")
     
 
        #Scraper.download_image(src, f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')
        
        
    def download_image(image_url, fp):
        img_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(img_data)

      

    def download_data(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
        
   


        

   


if __name__ == '__main__':
    imdb = Scraper()
    imdb.navigate_to_movie_table()
    imdb.get_movie_links()
    imdb.download_data()
    imdb.extract_text_data()
# Out:
# {'Star Wars: Episode VIII - The Last Jedi': {'WORLDWIDE': '$1,332,539,889', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$220,009,584\n4,232 theaters', 'Budget': '$317,000,000', 'Release Date': 'Dec 15, 2017 - Apr 19, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 32 min', 'Genres': 'Action Adventure Fantasy Sci-Fi', 'In Release': '382 days/54 weeks', 'Widest Release': '4,232 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_link': 'https://m.media-amazon.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_SY139_CR1,0,92,139_.jpg'}, 'Thor: Ragnarok': {'WORLDWIDE': '$853,977,126', 'Distributor': 'Walt Disney Studios Motion Pictures\nSee full company information', 'Opening': '$122,744,989\n4,080 theaters', 'Budget': '$180,000,000', 'Release Date': 'Nov 3, 2017 - Mar 15, 2018', 'MPAA': 'PG-13', 'Running Time': '2 hr 10 min', 'Genres': 'Action Adventure Comedy Fantasy Sci-Fi', 'In Release': '424 days/60 weeks', 'Widest Release': '4,080 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_link': 'https://m.media-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_SY139_CR1,0,92,139_.jpg'}, 'Blade Runner 2049': {'WORLDWIDE': '$259,239,658', 'Distributor': 'Warner Bros.\nSee full company information', 'Opening': '$32,753,122\n4,058 theaters', 'Budget': '$150,000,000', 'Release Date': 'Oct 6, 2017 - Feb 1, 2018', 'MPAA': 'R', 'Running Time': '2 hr 44 min', 'Genres': 'Action Drama Mystery Sci-Fi Thriller', 'In Release': '452 days/64 weeks', 'Widest Release': '4,058 theaters', 'IMDbPro': 'See more details at IMDbPro', 'image_link': 'https://m.media-amazon.com/images/M/MV5BNzA1Njg4NzYxOV5BMl5BanBnXkFtZTgwODk5NjU3MzI@._V1_SY139_CR1,0,92,139_.jpg'}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [154], line 157
#     155 imdb.get_movie_links()
#     156 imdb.download_data()
# --> 157 imdb.extract_text_data()
#
# Cell In [154], line 103, in Scraper.extract_text_data(self)
#     100 timestr = time.strftime("%Y%m%d_%H%M%S")
#     102 for value in self.movie_dictionary:
# --> 103     Scraper.download_image(value['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')
#
# TypeError: string indices must be integers

# %%
# Milestone 5, Task 1A - Refactor and optimise current code


from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Applications/chromedriver' ):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        self.text_data_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

        time.sleep(3)

    def click_monthly_button(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def create_list_of_movie_links(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)
        
        for year in ('2017', '2018'): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)

        return(self.movie_link_list)

    def scrape_text_data_from_movie_links(self):
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.category_heading_list.append(worldwide_gross)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.category_value_list.append(international_gross)
            
            for text in div_tags:
                category_heading = text.find_element(by=By.XPATH, value='span[1]').text
                self.category_heading_list.append(category_heading)
                category_value = text.find_element(by=By.XPATH, value='span[2]').text
                self.category_value_list.append(category_value)
              
            text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
            return text_dictionary

    def scrape_movie_name_and_create_movie_dict(self):
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})  
        
        self.create_directories_and_download_movie_dict()     

        for n, movie in enumerate(self.movie_dictionary.values(),1):
            timestr = self.timestamp
            self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')       

    def create_timestamp_for_web_scrape(self):        
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   

    def download_image(self, image_url, fp):
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)

    def create_directories_and_download_movie_dict(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
     

if __name__ == '__main__':
    imdb = Scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links()
    imdb.scrape_movie_name_and_create_movie_dict()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [200], line 129
#     127 imdb.click_monthly_button()
#     128 imdb.create_list_of_movie_links()
# --> 129 imdb.scrape_movie_name_and_create_movie_dict()
#
# Cell In [200], line 83, in Scraper.scrape_movie_name_and_create_movie_dict(self)
#      81 def scrape_movie_name_and_create_movie_dict(self):
#      82     for link in (self.movie_link_list[0:3]):
# ---> 83         self.driver.get(link)
#      84         time.sleep(2)
#      85         div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:426, in WebDriver.execute(self, driver_command, params)
#     423         params['sessionId'] = self.session_id
#     425 params = self._wrap_value(params)
# --> 426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
#     428     self.error_handler.check_response(response)
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Documents/GitHub/DC_IMDB/DCvenv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
for movie in imdb.movie_dictionary.values():
    print(movie['image_link'])
# Out:
# https://m.media-amazon.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_SY139_CR1,0,92,139_.jpg
# https://m.media-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_SY139_CR1,0,92,139_.jpg
# https://m.media-amazon.com/images/M/MV5BNzA1Njg4NzYxOV5BMl5BanBnXkFtZTgwODk5NjU3MzI@._V1_SY139_CR1,0,92,139_.jpg

# %%
# Milestone 5, Task 1B - Refactor and optimise current code


from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Scraper:

    def __init__(self, url: str = "https://www.boxofficemojo.com/", driverpath: str = '/Applications/chromedriver'):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        self.text_data_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

        time.sleep(3)

    def click_monthly_button(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        
        self.select_year_from_scroll_down_menu()
        
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
    
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)

        return(self.movie_link_list)

    def scrape_text_data_from_movie_links(self):
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.category_heading_list.append(worldwide_gross)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.category_value_list.append(international_gross)
            
            for text in div_tags:
                category_heading = text.find_element(by=By.XPATH, value='span[1]').text
                self.category_heading_list.append(category_heading)
                category_value = text.find_element(by=By.XPATH, value='span[2]').text
                self.category_value_list.append(category_value)
              
            text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
            return text_dictionary

    def scrape_movie_name_and_create_movie_dict(self):
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})  
        
        self.create_directories_and_download_movie_dict()     

        for n, movie in enumerate(self.movie_dictionary.values(),1):
            timestr = self.timestamp
            self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')       

    def create_timestamp_for_web_scrape(self):        
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   

    def download_image(self, image_url, fp):
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)

    def create_directories_and_download_movie_dict(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
    

    

if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.scrape_movie_name_and_create_movie_dict()

# %%
# Milestone 5, Task 1C - Refactor and optimise current code


from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Web_link_scraper:
    def __init__(self, url: str="https://www.boxofficemojo.com/", driverpath: str='/Applications/chromedriver'):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        time.sleep(3)

    def click_monthly_button(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        self.select_year_from_scroll_down_menu()
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)
        return(self.movie_link_list)    


class Data_scraper(Web_link_scraper):
    def __init__(self):
        super().__init__()
        self.text_data_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

    def scrape_text_data_from_movie_links(self):
            summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
            div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
            performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
            worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
            worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
            self.category_heading_list.append(worldwide_gross)
            international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
            self.category_value_list.append(international_gross)
            
            for text in div_tags:
                category_heading = text.find_element(by=By.XPATH, value='span[1]').text
                self.category_heading_list.append(category_heading)
                category_value = text.find_element(by=By.XPATH, value='span[2]').text
                self.category_value_list.append(category_value)
              
            text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
            return text_dictionary
        
    def scrape_movie_name_and_create_movie_dict(self):
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})  
        self.create_directories_and_download_movie_dict()     

        for n, movie in enumerate(self.movie_dictionary.values(),1):
            timestr = self.timestamp
            self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')   
    
    def create_timestamp_for_web_scrape(self):        
            time_key = 'timestamp'
            self.category_heading_list.append(time_key)
            self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   

    def download_image(self, image_url, fp):
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)

    def create_directories_and_download_movie_dict(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
    
    

if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Data_scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.scrape_movie_name_and_create_movie_dict()

# %%
import json
from typing import Any


def save_to_json(
    file_path: str,
    object_to_save: Any,
    indent: int
):
    try:
        with open(file_path, "w") as outfile:
            json.dump(object_to_save, outfile, indent=indent)
        return True
    except Exception as e:
        print(e)
        return False

# %%
# Original file

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Web_link_scraper:
    '''
    This class scrapes a list of links from the IMDB website for a list of years that you specify and 
    creates a list of movie links.
    
    Attributes:
    ----------
    service : class
        Manages the starting and stopping of the ChromeDriver.
    options : class
        Used to create an instance of the chrome driver.
    driver : object
        Gets the url.
    movie_link_list : list
        Creates a list of web elements corresponding to each movie from the IMDB website.
    category_heading_list : list
        Creates a list of all the column headings from the table of information for each movie link.
    '''        
    def __init__(self, url: str="https://www.boxofficemojo.com/", driverpath: str='/Applications/chromedriver'):     
        '''
        The function initialises the class and takes in a url and a driverpath. 
        The options and service object creates a driver object that is used to get the url.
        The function sleeps for 3 seconds to allow the webpage to fully load.
        
        Parameters
        ----------
        url : str, optional
            The url of the website you want to scrape.
        driverpath : str, optional
            This is the path to the chromedriver executable.
        
        '''
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        time.sleep(3)

    def click_monthly_button(self):
        '''
        The function clicks the monthly button on the web home page.

        '''
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        '''
        The function selects the year from the drop down menu.
        
        '''
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        '''
        This function takes a list of years as an argument, and then loops through each 
        year to get a list of web links corresponding to each movie.
        
        Parameters
        ----------
        year_list
            a list of years that you want to scrape
        
        Returns
        -------
            A list of movie links.
        
        '''
        self.select_year_from_scroll_down_menu()
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)
        return(self.movie_link_list)    


class Data_scraper(Web_link_scraper):                                                                               
    '''
    This class inherits the Web_link_scraper and iterates through each web link in the movie_link_list 
    scraping relevant data corresponding to each movie.

    Attributes:
    ----------
    
    This is a child class and inherits all attributes in the Web_link scraper class in addition
    to the attributes listed below.
    
    text_data_dictionary : dict
        Dictionary containing text data for each movie.

    movie_dictionary : dict
        Dictionary containing all data corresponding to each movie.

    timestamp : int
        Provides date and time that each movie link is scraped in the format: :%Y-%m-%d %H:%M:%S.  
    '''
    def __init__(self):
        '''
        This function initializes the class by creating a dictionary for the text data, a dictionary for
        the movie data, and a timestamp.   
        '''
        super().__init__()
        self.text_data_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

    def scrape_text_data_from_movie_links(self):
        '''
        This function scrapes text data from the table of values presented on each web page (movie_link) 
        and forms two lists; category headings and corresponding values. 
        The zip object passes both lists and yields tuples stored to text_dictionary. 
        
        Returns
        -------
            A dictionary of the movie's text data.
        
        '''
        summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
        div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
        performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
        worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
        self.category_heading_list.append(worldwide_gross)
        international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
        self.category_value_list.append(international_gross)
            
        for text in div_tags:
            category_heading = text.find_element(by=By.XPATH, value='span[1]').text
            self.category_heading_list.append(category_heading)
            category_value = text.find_element(by=By.XPATH, value='span[2]').text
            self.category_value_list.append(category_value)
              
        text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
        return text_dictionary
        
    def scrape_movie_name_and_create_movie_dict(self):
        '''
        This function iterates through each web link stored in the movie_link_list and calls 
        relevant functions to: 
        (ii)    scrape all text data,
        (iii)   scrape image data,
        (iv)    record the timestamp for each scrape.
        The above data is stored in the image_and_text_dictionary.

        The movie-dictionary is created to organise and store all relevant data according 
        to each movie's name (serving as a unique id).  

        All images in the movie_dictionary are downloaded in order to a directory for preservation.
        '''
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})  
        self.create_directories_and_download_movie_dict()     

        for n, movie in enumerate(self.movie_dictionary.values(),1):
            timestr = self.timestamp
            self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')   
        
        self.driver.quit()
    
    def create_timestamp_for_web_scrape(self):      
        '''
        This function creates a timestamp for the web scrape. 

        '''
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        '''
        The function scrapes the image data from the IMDB website.
        
        Returns
        -------
            The image source is being returned.
        
        '''
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   

    def download_image(self, image_url, fp):
        '''
        Downloads an image from a URL and saves it to a file path.
        
        Parameters
        ----------
        image_url
            The URL of the image you want to download.
        fp
            file path
        
        '''
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)

    def create_directories_and_download_movie_dict(self):
        '''
        Creates a subdirectory called 'box_office_mojo'
        and writes movie_dictionary to it in JSON format. 
        Downloaded images are stored in a seperate directory under 'box_office_mojo' called 'images.'    
        Above is stored under the main directory: 'raw_data.'
        '''
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
    
    

if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Data_scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.scrape_movie_name_and_create_movie_dict()

# %%
# First edit

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Web_link_scraper:
    '''
    This class scrapes a list of links from the IMDB website for a list of years that you specify and 
    creates a list of movie links.
    
    Attributes:
    ----------
    service : class
        Manages the starting and stopping of the ChromeDriver.
    options : class
        Used to create an instance of the chrome driver.
    driver : object
        Gets the url.
    movie_link_list : list
        Creates a list of web elements corresponding to each movie from the IMDB website.
    category_heading_list : list
        Creates a list of all the column headings from the table of information for each movie link.
    '''        
    def __init__(self, url: str="https://www.boxofficemojo.com/", driverpath: str='/Applications/chromedriver'):     
        '''
        The function initialises the class and takes in a url and a driverpath. 
        The options and service object creates a driver object that is used to get the url.
        The function sleeps for 3 seconds to allow the webpage to fully load.
        
        Parameters
        ----------
        url : str, optional
            The url of the website you want to scrape.
        driverpath : str, optional
            This is the path to the chromedriver executable.
        
        '''
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        time.sleep(3)

    def click_monthly_button(self):
        '''
        The function clicks the monthly button on the web home page.

        '''
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        '''
        The function selects the year from the drop down menu.
        
        '''
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        '''
        This function takes a list of years as an argument, and then loops through each 
        year to get a list of web links corresponding to each movie.
        
        Parameters
        ----------
        year_list
            a list of years that you want to scrape
        
        Returns
        -------
            A list of movie links.
        
        '''
        self.select_year_from_scroll_down_menu()
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)
        return(self.movie_link_list)    


class Data_scraper(Web_link_scraper):                                                                               
    '''
    This class inherits the Web_link_scraper and iterates through each web link in the movie_link_list 
    scraping relevant data corresponding to each movie.

    Attributes:
    ----------
    
    This is a child class and inherits all attributes in the Web_link scraper class in addition
    to the attributes listed below.
    
    text_data_dictionary : dict
        Dictionary containing text data for each movie.

    movie_dictionary : dict
        Dictionary containing all data corresponding to each movie.

    timestamp : int
        Provides date and time that each movie link is scraped in the format: :%Y-%m-%d %H:%M:%S.  
    '''
    def __init__(self):
        '''
        This function initializes the class by creating a dictionary for the text data, a dictionary for
        the movie data, and a timestamp.   
        '''
        super().__init__()
        self.text_data_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

    def scrape_text_data_from_movie_links(self):
        '''
        This function scrapes text data from the table of values presented on each web page (movie_link) 
        and forms two lists; category headings and corresponding values. 
        The zip object passes both lists and yields tuples stored to text_dictionary. 
        
        Returns
        -------
            A dictionary of the movie's text data.
        
        '''
        summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
        div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
        performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
        worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
        self.category_heading_list.append(worldwide_gross)
        international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
        self.category_value_list.append(international_gross)
            
        for text in div_tags:
            category_heading = text.find_element(by=By.XPATH, value='span[1]').text
            self.category_heading_list.append(category_heading)
            category_value = text.find_element(by=By.XPATH, value='span[2]').text
            self.category_value_list.append(category_value)

        return self.category_heading_list, self.category_value_list

    def create_text_dictionary(self):
        self.scrape_text_data_from_movie_links()
        text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
        return text_dictionary
        
    def scrape_movie_name_and_create_movie_dict(self):
        '''
        This function iterates through each web link stored in the movie_link_list and calls 
        relevant functions to: 
        (ii)    scrape all text data,
        (iii)   scrape image data,
        (iv)    record the timestamp for each scrape.
        The above data is stored in the image_and_text_dictionary.

        The movie-dictionary is created to organise and store all relevant data according 
        to each movie's name (serving as a unique id).  

        All images in the movie_dictionary are downloaded in order to a directory for preservation.
        '''
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            image_and_text_dictionary = self.create_text_dictionary()
            image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})  
        self.create_directories_and_download_movie_dict()     

        for n, movie in enumerate(self.movie_dictionary.values(),1):
            timestr = self.timestamp
            self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')   
        
        self.driver.quit()
    
    def create_timestamp_for_web_scrape(self):      
        '''
        This function creates a timestamp for the web scrape. 

        '''
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        '''
        The function scrapes the image data from the IMDB website.
        
        Returns
        -------
            The image source is being returned.
        
        '''
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   

    def download_image(self, image_url, fp):
        '''
        Downloads an image from a URL and saves it to a file path.
        
        Parameters
        ----------
        image_url
            The URL of the image you want to download.
        fp
            file path
        
        '''
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)

    def create_directories_and_download_movie_dict(self):
        '''
        Creates a subdirectory called 'box_office_mojo'
        and writes movie_dictionary to it in JSON format. 
        Downloaded images are stored in a seperate directory under 'box_office_mojo' called 'images.'    
        Above is stored under the main directory: 'raw_data.'
        '''
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
    
    

if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Data_scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.scrape_movie_name_and_create_movie_dict()

# %%
# Original file without doc strings

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Web_link_scraper:      
    def __init__(self, url: str="https://www.boxofficemojo.com/", driverpath: str='/Applications/chromedriver'):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        time.sleep(3)

    def click_monthly_button(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        self.select_year_from_scroll_down_menu()
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)
        return(self.movie_link_list)    


class Data_scraper(Web_link_scraper):                                                                              
    def __init__(self):
        super().__init__()
        self.text_data_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

    def scrape_text_data_from_movie_links(self):
        summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
        div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
        performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
            
        worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
        self.category_heading_list.append(worldwide_gross)
        international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
        self.category_value_list.append(international_gross)
            
        for text in div_tags:
            category_heading = text.find_element(by=By.XPATH, value='span[1]').text
            self.category_heading_list.append(category_heading)
            category_value = text.find_element(by=By.XPATH, value='span[2]').text
            self.category_value_list.append(category_value)
              
        text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
        return text_dictionary
        
    def scrape_movie_name_and_create_movie_dict(self):
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})  
        self.create_directories_and_download_movie_dict()     

        for n, movie in enumerate(self.movie_dictionary.values(),1):
            timestr = self.timestamp
            self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')   
        
        self.driver.quit()
    
    def create_timestamp_for_web_scrape(self):      
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   

    def download_image(self, image_url, fp):
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)

    def create_directories_and_download_movie_dict(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
    
    

if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Data_scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.scrape_movie_name_and_create_movie_dict()

# %%
# Refactoring code for testing v2 - returns movie dictionary

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
import time
import datetime
import json
import os
import requests


class Web_link_scraper:      
    def __init__(self, url: str="https://www.boxofficemojo.com/", driverpath: str='/Applications/chromedriver'):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        time.sleep(3)

    def click_monthly_button(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        self.select_year_from_scroll_down_menu()
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)
        return(self.movie_link_list)    


class Data_scraper(Web_link_scraper):                                                                              
    def __init__(self):
        super().__init__()
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

    def scrape_text_data_from_movie_links(self):
        summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
        div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
        performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
                
        worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
        self.category_heading_list.append(worldwide_gross)
        international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
        self.category_value_list.append(international_gross)
            
        for text in div_tags:
            category_heading = text.find_element(by=By.XPATH, value='span[1]').text
            self.category_heading_list.append(category_heading)
            category_value = text.find_element(by=By.XPATH, value='span[2]').text
            self.category_value_list.append(category_value)
              
        text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
        return text_dictionary
        
    def create_movie_dictionary(self):
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(2)
            self.create_timestamp_for_web_scrape()
            self.scrape_text_data_from_movie_links()
            image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            image_link = self.scrape_image_data()
            image_and_text_dictionary.update({'image_link':image_link})

            movie_name = self.get_movie_name()
            self.movie_dictionary.update({movie_name:image_and_text_dictionary})
   
        return self.movie_dictionary

    def create_timestamp_for_web_scrape(self):      
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   
             
    def get_movie_name(self):
        div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
        movie_title = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text

    def create_directories_and_download_movie_dict(self):
        os.mkdir('raw_data')
        path = os.path.join('raw_data', 'box_office_mojo')
        os.mkdir(path)
        with open(os.path.join(path, 'data.json'), 'w') as f:
            json.dump(self.movie_dictionary, f)
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
        
    
    


    
    
    

if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Data_scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.scrape_movie_name_and_create_movie_dict()

# %%
# Creates method to dump movie_dict into json file: v3 **Completed - final edit**

from selenium import webdriver
from selenium.webdriver.common. by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
from typing import Any
import time
import datetime
import json
import os
import requests


class Web_link_scraper:    
    def __init__(self, url: str="https://www.boxofficemojo.com/", driverpath: str='/Applications/chromedriver'):     
        self.service = Service(driverpath)
        self.options = Options()
        self.driver = webdriver.Chrome(options=self.options, service=self.service) 
        self.driver.get(url)
        self.movie_link_list = []
        self.category_heading_list = []
        self.category_value_list = []
        time.sleep(3)

    def click_monthly_button(self):
        domestic_container = self.driver.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div') 
        monthly_button = domestic_container.find_element(by=By.XPATH, value='//*[@id="a-page"]/div[2]/div[4]/div/a[4]') 
        monthly_button.click()
        time.sleep(3)

    def select_year_from_scroll_down_menu(self):
        drop_down_list = self.driver.find_element(by=By.XPATH, value='//select[@id="view-navSelector"]') 
        select = Select(drop_down_list)
        select.select_by_visible_text('By year')
        time.sleep(3)

    def create_list_of_movie_links(self, year_list):    
        self.select_year_from_scroll_down_menu()
        for year in (year_list): 
            drop_down_by_year = self.driver.find_element(by=By.XPATH, value='//select[@id="by-year-navSelector"]')
            select = Select(drop_down_by_year)
            select.select_by_visible_text(year)
            time.sleep(3)

            movie_table = self.driver.find_element(by=By.XPATH, value='//*[@id="table"]/div/table[2]/tbody')
            movie_list = movie_table.find_elements(by=By.XPATH, value='//*[@class="a-text-left mojo-field-type-release mojo-cell-wide"]')
            for movie in movie_list:
                a_tag = movie.find_element(by=By.TAG_NAME, value='a')
                link = a_tag.get_attribute('href')
                self.movie_link_list.append(link)
        print(self.movie_link_list)
        # print(len(self.movie_link_list))
        return(self.movie_link_list)    


class Data_scraper(Web_link_scraper):                                                                              
    def __init__(self):
        super().__init__()
        self.image_and_text_dictionary = {}
        self.movie_dictionary = {}
        self.timestamp = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
        self.file_path = os.path.join('raw_data', 'box_office_mojo')

    def scrape_text_data_from_movie_links(self):
        summary_table = self.driver.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"]')
        div_tags = summary_values.find_elements(by=By.XPATH, value='./div[@class="a-section a-spacing-none"]')
        performance_summary_values = summary_table.find_element(by=By.XPATH, value='//div[@class="a-section a-spacing-none mojo-gutter mojo-summary-table"]')
        worldwide_values = performance_summary_values.find_element(by=By.XPATH, value='//div[3][@class="a-section a-spacing-none"]')
        worldwide_gross = worldwide_values.find_element(by=By.XPATH, value='span[1]/a').text
        self.category_heading_list.append(worldwide_gross)
        international_gross = worldwide_values.find_element(by=By.XPATH, value='span[2]/a/span').text
        self.category_value_list.append(international_gross)        

        for text in div_tags:
            category_heading = text.find_element(by=By.XPATH, value='span[1]').text
            self.category_heading_list.append(category_heading)
            category_value = text.find_element(by=By.XPATH, value='span[2]').text
            self.category_value_list.append(category_value)
              
        text_dictionary = dict(zip(self.category_heading_list, self.category_value_list))
        #print(text_dictionary)
        return text_dictionary
        
    def create_movie_dictionary(self):
        for link in (self.movie_link_list[0:3]):
            self.driver.get(link)
            time.sleep(4)
            div_tag = self.driver.find_element(by=By.XPATH, value='//div[@class="a-fixed-left-grid-col a-col-right"]')
            movie_name = div_tag.find_element(by=By.XPATH, value='h1[@class="a-size-extra-large"]').text      
            self.create_timestamp_for_web_scrape()
            image_link = self.scrape_image_data()
            self.image_and_text_dictionary = self.scrape_text_data_from_movie_links()
            self.image_and_text_dictionary.update({'image_link':image_link})
            self.movie_dictionary.update({movie_name:self.image_and_text_dictionary})
        return self.movie_dictionary
            
    def create_timestamp_for_web_scrape(self):      
        time_key = 'timestamp'
        self.category_heading_list.append(time_key)
        self.category_value_list.append(self.timestamp)

    def scrape_image_data(self):
        image_results = self.driver.find_element(By.XPATH, value = '//*[@class="a-section a-spacing-none mojo-posters"]')
        img_tag = image_results.find_element(by=By.TAG_NAME, value='img')
        src = img_tag.get_attribute('src')
        return src   
             
    def create_directories(self):
        os.mkdir('raw_data')
        os.mkdir(self.file_path)
        
    def save_to_json(self, file_path: str, object_to_save: Any, indent: int):
        try:
            with open(os.path.join(self.file_path, 'data.json'), "w") as outfile:
                json.dump(self.movie_dictionary, outfile, indent=indent)
            return True
        
        except Exception as e:
            print(e)
            return False

    def create_image_directory(self):
        image_path = 'raw_data/box_office_mojo/images'
        os.mkdir(image_path)
        for n, movie in enumerate(self.movie_dictionary.values(),1):
                timestr = self.timestamp
                self.download_image(movie['image_link'], f'raw_data/box_office_mojo/images/{timestr}_{n}.jpg')     
    
    def download_image(self, image_url, fp):
        image_data = requests.get(image_url, fp).content
        with open(fp, 'wb') as handler:
            handler.write(image_data)
        

    
    
if __name__ == '__main__':
    year_list = ['2017', '2018']
    imdb = Data_scraper()
    imdb.click_monthly_button()
    imdb.create_list_of_movie_links(year_list)
    imdb.create_movie_dictionary()
    imdb.create_directories()
    imdb.create_image_directory()
    imdb.save_to_json(str, Any, 4)
# Out:
# ['https://www.boxofficemojo.com/release/rl2708702721/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl2959312385/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl444564993/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl3481241089/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2541716993/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl863208961/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl578455041/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl2976089601/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl1767212545/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl222594561/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl660506113/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl2557707777/?ref_=bo_my_table_12', 'https://www.boxofficemojo.com/release/rl3108800001/?ref_=bo_my_table_1', 'https://www.boxofficemojo.com/release/rl3075966465/?ref_=bo_my_table_2', 'https://www.boxofficemojo.com/release/rl2734720513/?ref_=bo_my_table_3', 'https://www.boxofficemojo.com/release/rl1493206529/?ref_=bo_my_table_4', 'https://www.boxofficemojo.com/release/rl2449573377/?ref_=bo_my_table_5', 'https://www.boxofficemojo.com/release/rl2088535553/?ref_=bo_my_table_6', 'https://www.boxofficemojo.com/release/rl2071758337/?ref_=bo_my_table_7', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_8', 'https://www.boxofficemojo.com/release/rl3043198465/?ref_=bo_my_table_9', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_10', 'https://www.boxofficemojo.com/release/rl2992866817/?ref_=bo_my_table_11', 'https://www.boxofficemojo.com/release/rl3095234049/?ref_=bo_my_table_12']
